# %%
# Import Libraries
import bs4
import requests
import numpy as np
import pandas as pd

# %%
URL = 'https://www.amazon.com/s?k=data+science&crid=1LTLR6XBURI0W&sprefix=data+science%2Caps%2C320&ref=nb_sb_noss_2'

# %%
# Headers for request
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
# HTTP request
page = requests.get(URL,headers=headers)
page.content
# Out:
# b'<!doctype html><html lang="en-us" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-na.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function
# ...

# %%
# Creating Soup object containing all webpage content
soup = bs4.BeautifulSoup(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
# Fetching the links as list of Tags
links = soup.find_all('a', attrs = {'class' : "a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"})
links[0]
# Out:
# <a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&amp;adId=A0254314293DC7CDKHZNB&amp;qualifier=1684465655&amp;id=6022879176494945&amp;widgetName=sp_atf&amp;url=%2FAce-Data-Science-Interview-Questions%2Fdp%2F0578973839%2Fref%3Dsr_1_1_sspa%3Fcrid%3D1LTLR6XBURI0W%26keywords%3Ddata%2Bscience%26qid%3D1684465655%26sprefix%3Ddata%2Bscience%252Caps%252C320%26sr%3D8-1-spons%26psc%3D1"><span class="a-size-base-plus a-color-base a-text-normal">Ace the Data Science Interview: 201 Real Interview Questions Asked By FAANG, Tech Startups, &amp; Wall Street</span> </a>

# %%
for link in links:
    print(link.get('href'),'\n')
# Out:
# /gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A0254314293DC7CDKHZNB&qualifier=1684465655&id=6022879176494945&widgetName=sp_atf&url=%2FAce-Data-Science-Interview-Questions%2Fdp%2F0578973839%2Fref%3Dsr_1_1_sspa%3Fcrid%3D1LTLR6XBURI0W%26keywords%3Ddata%2Bscience%26qid%3D1684465655%26sprefix%3Ddata%2Bscience%252Caps%252C320%26sr%3D8-1-spons%26psc%3D1
#
# /gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A08147232A5DDRE0H87JF&qualifier=1684465655&id=6022879176494945&widgetName=sp_atf&url=%2FBuild-Career-Science-Jacqueline-Nolis%2Fdp%2F1617296244%2Fref%3Dsr_1_2_sspa%3Fcrid%3D1LTLR6XBURI0W%26keywords%3Ddata%2Bscience%26qid%3D1684465655%26sprefix%3Ddata%2Bscience%252Caps%252C320%26sr%3D8-2-spons%26psc%3D1
#
# ...

# %%
len(links)
# Out:
# 59

# %%
# Deleting links of sponsored Items
for link in links:
    if 'https://' in link.get('href'):
        links.remove(link)
len(links)
# Out:
# 59

# %%
# Creating Soup object for the first item's Webpage
url = 'http://www.amazon.com'+links[0].get('href')
print(url)
new_page = requests.get(url, headers=headers)
new_soup = bs4.BeautifulSoup(new_page.content, 'html.parser')
# Out:
# http://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A0254314293DC7CDKHZNB&qualifier=1684465655&id=6022879176494945&widgetName=sp_atf&url=%2FAce-Data-Science-Interview-Questions%2Fdp%2F0578973839%2Fref%3Dsr_1_1_sspa%3Fcrid%3D1LTLR6XBURI0W%26keywords%3Ddata%2Bscience%26qid%3D1684465655%26sprefix%3Ddata%2Bscience%252Caps%252C320%26sr%3D8-1-spons%26psc%3D1

# %%
# Getting Product Title
try:
    title = new_soup.find('span', attrs={'id':'productTitle'}).text.strip()
except AttributeError:
    title = None
title
# Out:
# 'Ace the Data Science Interview: 201 Real Interview Questions Asked By FAANG, Tech Startups, & Wall Street'

# %%
# Getting Price
try:
    price = new_soup.find('span', attrs={'id':'price'}).text.strip()
except AttributeError:
    try:
        price = new_soup.find("span", attrs={'class':'a-price a-text-price header-price a-size-base a-text-normal'}).find('span', attrs={'class':'a-offscreen'}).text.strip()
    except:
        price = 'NONE'
price
# Out:
# '$35.53'

# %%
# Getting Star Ratings
try:
    rating = new_soup.find('i', attrs={'class':'a-icon a-icon-star a-star-4-5 cm-cr-review-stars-spacing-big'}).text.strip()
except AttributeError:
        try:
            rating = new_soup.find("span", attrs={'class':'a-icon-alt'}).text.strip()
        except:
            rating = 'NONE'
rating
# Out:
# '4.5 out of 5 stars'

# %%
# Getting User Reviews
try:
    reviews = new_soup.find('span', attrs={'id':'acrCustomerReviewText'}).text.strip()
except AttributeError:
    reviews = 'NONE'
reviews
# Out:
# '798 ratings'

# %%
# Getting Availability Status
try:
    availability = new_soup.find('span', attrs={'class':'a-size-medium a-color-success'}).text.strip()
except AttributeError:
    availability = 'NONE'
availability
# Out:
# 'In Stock'

# %% [markdown]
# ## Let's Create Our Final Web Scraper

# %%
def get_title(soup):
    try:
        title = soup.find('span', attrs={'id':'productTitle'}).text.strip()
    except AttributeError:
        title = None
    return title

# %%
def get_price(soup):
    try:
        price = soup.find('span', attrs={'id':'price'}).text.strip()
    except AttributeError:
        try:
            price = soup.find("span", attrs={'class':'a-price a-text-price header-price a-size-base a-text-normal'}).find('span', attrs={'class':'a-offscreen'}).text.strip()
        except:
            price = 'NONE'
    return price

# %%
def get_rating(soup):
    try:
        rating = soup.find('i', attrs={'class':'a-icon a-icon-star a-star-4-5 cm-cr-review-stars-spacing-big'}).text.strip()
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = 'NONE'
    return rating

# %%
def get_review_count(soup):
    try:
        review_count = soup.find('span', attrs={'id':'acrCustomerReviewText'}).text.strip()
    except AttributeError:
        review_count = 'NONE'
    return review_count

# %%
def get_availabilty(soup):
    try:
        availability = soup.find('span', attrs={'class':'a-size-medium a-color-success'}).text.strip()
    except AttributeError:
        availability = 'NONE'
    return availability

# %%
URL = 'https://www.amazon.com/s?k=data+science&crid=1LTLR6XBURI0W&sprefix=data+science%2Caps%2C320&ref=nb_sb_noss_2'

# Headers for request
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# HTTP request
webpage = requests.get(URL, headers = HEADERS)

# Creating Soup object
soup1 = bs4.BeautifulSoup(webpage.content, 'html.parser')

# Fetching the links as list of Tags
links = soup1.find_all('a', attrs = {'class' : "a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"})

# Removing sponsored item links
for link in links:
    if 'https://' in link.get('href'):
        links.remove(link)
        
# Creating a List of links
link_list = []
for link in links:
    link_list.append('http://www.amazon.com'+link.get('href'))

# Creating a dictionary
dct = {'Title':[], 'Price':[],'Rating':[],'Review_Count':[],'Availability':[]}

# Extracting data from each product by Looping through Product Links
for link in link_list:
    
    inner_page = requests.get(link, headers = HEADERS)
    
    soup2 = bs4.BeautifulSoup(inner_page.content, 'html.parser')
    
    # Calling functions to load data in dictionary
    dct['Title'].append(get_title(soup2))
    dct['Price'].append(get_price(soup2))
    dct['Rating'].append(get_rating(soup2))
    dct['Review_Count'].append(get_review_count(soup2))
    dct['Availability'].append(get_availabilty(soup2))

# Creating DataFrame from Dictionary    
df = pd.DataFrame.from_dict(dct)
df = df.dropna(subset=['Title'])
df.head(50)
# Out:
#                                                 Title   Price  \
# 0   Ace the Data Science Interview: 201 Real Inter...  $35.53
# 1                      Build a Career in Data Science  $39.99
# 2   Microsoft Power BI Quick Start Guide: The ulti...  $33.50
# 3   Data Engineering with Google Cloud Platform: A...  $41.59
# 4   Essential Math for Data Science: Take Control ...    NONE
# 5   Becoming a Data Head: How to Think, Speak, and...  $24.49
# 6   Data Science from Scratch: First Principles wi...  $46.22
# 7   The Kaggle Workbook: Self-learning exercises a...  $24.99
# 8   How to Become a Data Scientist: A Guide for Es...  $24.99
# 9   Data Science for Beginners: An Introduction to...    NONE
# 10  Forecasting Time Series Data with Prophet: Bui...  $44.99
# 11  The Data Science Manual: A Comprehensive Guide...    NONE
# 12  How Data Happened: A History from the Age of R...  $27.00
# 13  Applied Geospatial Data Science with Python: L...  $54.99
# ...

# %%
df
# Out:
#                                                 Title   Price  \
# 0   Ace the Data Science Interview: 201 Real Inter...  $35.53
# 1                      Build a Career in Data Science  $39.99
# 2   Microsoft Power BI Quick Start Guide: The ulti...  $33.50
# 3   Data Engineering with Google Cloud Platform: A...  $41.59
# 4   Essential Math for Data Science: Take Control ...    NONE
# ..                                                ...     ...
# 62  Thinking Clearly with Data: A Guide to Quantit...  $29.95
# 63  R for Data Science: Import, Tidy, Transform, V...  $78.38
# 64  The Kaggle Book: Data analysis and machine lea...  $37.16
# 65  The Python Bible 7 in 1: Volumes One To Seven ...    NONE
# 66  Designing Data-Intensive Applications: The Big...    NONE
#
#                 Rating   Review_Count Availability
# 0   4.5 out of 5 stars    798 ratings     In Stock
# 1   4.7 out of 5 stars     98 ratings     In Stock
# 2   4.2 out of 5 stars     51 ratings     In Stock
# ...

# %%
for link in link_list:
    print(link,'\n')
# Out:
# http://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A0254314293DC7CDKHZNB&url=%2FAce-Data-Science-Interview-Questions%2Fdp%2F0578973839%2Fref%3Dsr_1_1_sspa%3Fcrid%3D1LTLR6XBURI0W%26keywords%3Ddata%2Bscience%26qid%3D1684465685%26sprefix%3Ddata%2Bscience%252Caps%252C320%26sr%3D8-1-spons%26psc%3D1&qualifier=1684465685&id=2257849573569388&widgetName=sp_atf
#
# http://www.amazon.com/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A08147232A5DDRE0H87JF&url=%2FBuild-Career-Science-Jacqueline-Nolis%2Fdp%2F1617296244%2Fref%3Dsr_1_2_sspa%3Fcrid%3D1LTLR6XBURI0W%26keywords%3Ddata%2Bscience%26qid%3D1684465685%26sprefix%3Ddata%2Bscience%252Caps%252C320%26sr%3D8-2-spons%26psc%3D1&qualifier=1684465685&id=2257849573569388&widgetName=sp_atf
#
# ...
